# %%
import leafmap.maplibregl as leafmap

# %%
m = leafmap.Map(style="liberty", projection="globe")
m
# Out:
# Html(children=[<leafmap.maplibregl.Map object at 0x7159e0f51e80>, Card(children=[Btn(children=[Icon(children=[…
